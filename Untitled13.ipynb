# %% [markdown]
# <a href="https://colab.research.google.com/github/joaosouza2/joaosouza2/blob/main/Untitled13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
-from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# instalação do kaldi
# !apt install unzip
# !wget https://github.com/kaldi-asr/kaldi/archive/refs/heads/master.zip
# !unzip master.zip

# instalação do ufpalign-main
# !wget https://github.com/falabrasil/ufpalign/archive/refs/heads/main.zip
# !unzip main.zip
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
#   inflating: kaldi-master/egs/sre08/v1/sid/train_ivector_extractor_dnn.sh
#     linking: kaldi-master/egs/sre08/v1/steps  -> ../../wsj/s5/steps
#     linking: kaldi-master/egs/sre08/v1/utils  -> ../../wsj/s5/utils
#    creating: kaldi-master/egs/sre10/
#   inflating: kaldi-master/egs/sre10/README.txt
#    creating: kaldi-master/egs/sre10/v1/
#   inflating: kaldi-master/egs/sre10/v1/README.txt
#   inflating: kaldi-master/egs/sre10/v1/cmd.sh
#    creating: kaldi-master/egs/sre10/v1/conf/
#   inflating: kaldi-master/egs/sre10/v1/conf/mfcc.conf
#   inflating: kaldi-master/egs/sre10/v1/conf/vad.conf
#    creating: kaldi-master/egs/sre10/v1/local/
#   inflating: kaldi-master/egs/sre10/v1/local/cosine_scoring.sh
#   inflating: kaldi-master/egs/sre10/v1/local/det_curve_example.sh
#    creating: kaldi-master/egs/sre10/v1/local/dnn/
#   inflating: kaldi-master/egs/sre10/v1/local/dnn/README
# ...

# %%
import os
os.chdir("/content/kaldi-master/tools")
# !bash extras/check_dependencies.sh
# Out:
# extras/check_dependencies.sh: sox is not installed.
# extras/check_dependencies.sh: neither libtoolize nor glibtoolize is installed
# extras/check_dependencies.sh: subversion is not installed
# extras/check_dependencies.sh: python2.7 is installed, but the python2 binary does not exist. Creating a symlink and adding this to tools/env.sh
# extras/check_dependencies.sh: WARNING python 2.7 is not the default python. We fixed this by adding a correct symlink more prominently on the path.
#  ... If you really want to use python 3.10.11 as default, add an empty file /content/kaldi-master/tools/python/.use_default_python and run this script again.
# extras/check_dependencies.sh: Intel MKL does not seem to be installed.
#  ... Run extras/install_mkl.sh to install it. Some distros (e.g., Ubuntu 20.04) provide
#  ... a version of MKL via the package manager, but verify that it is up-to-date.
#  ... You can also use other matrix algebra libraries. For information, see:
# ...

# %%
# !bash extras/install_mkl.sh
# Out:
# extras/install_mkl.sh: Your system is using debian-style package management.
# + apt-get update
# Hit:1 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu focal InRelease
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu focal-cran40/ InRelease [3,622 B]
# Hit:3 http://ppa.launchpad.net/cran/libgit2/ubuntu focal InRelease
# Hit:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  InRelease
# Get:5 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu focal InRelease [18.1 kB]
# Hit:6 http://archive.ubuntu.com/ubuntu focal InRelease
# Get:7 http://archive.ubuntu.com/ubuntu focal-updates InRelease [114 kB]
# Hit:8 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu focal InRelease
# Hit:9 http://ppa.launchpad.net/ubuntugis/ppa/ubuntu focal InRelease
# Get:10 http://security.ubuntu.com/ubuntu focal-security InRelease [114 kB]
# Get:11 http://archive.ubuntu.com/ubuntu focal-backports InRelease [108 kB]
# ...

# %%
# !apt install sox
# !apt install libtool
# !apt install subversion
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   libopencore-amrnb0 libopencore-amrwb0 libsox-fmt-alsa libsox-fmt-base
#   libsox3
# Suggested packages:
#   libsox-fmt-all
# The following NEW packages will be installed:
#   libopencore-amrnb0 libopencore-amrwb0 libsox-fmt-alsa libsox-fmt-base
#   libsox3 sox
# 0 upgraded, 6 newly installed, 0 to remove and 34 not upgraded.
# Need to get 513 kB of archives.
# After this operation, 1,564 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/universe amd64 libopencore-amrnb0 amd64 0.1.5-1 [94.8 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal/universe amd64 libopencore-amrwb0 amd64 0.1.5-1 [49.1 kB]
# Get:3 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 libsox3 amd64 14.4.2+git20190427-2+deb11u2build0.20.04.1 [225 kB]
# ...

# %%
# !make
# Out:
# extras/check_dependencies.sh
# extras/check_dependencies.sh: all OK.
# if [ -d "" ]; then \
#   cp -p "/cub-1.8.0.tar.gz" .; \
# else \
#   wget -nv -T 10 -t 3 -O cub-1.8.0.tar.gz \
#     https://github.com/NVlabs/cub/archive/1.8.0.tar.gz; \
# fi
# 2023-05-23 12:29:30 URL:https://codeload.github.com/NVlabs/cub/tar.gz/refs/tags/1.8.0 [384644] -> "cub-1.8.0.tar.gz" [1]
# rm -f cub
# tar -xmzf cub-1.8.0.tar.gz
# ln -s cub-1.8.0 cub
# if [ -d "" ]; then \
#   cp -p "/openfst-1.7.2.tar.gz" .; \
# else \
#   wget -nv -T 10 -t 1 http://www.openfst.org/twiki/pub/FST/FstDownload/openfst-1.7.2.tar.gz || \
#   wget -nv -T 10 -t 3 -c https://www.openslr.org/resources/2/openfst-1.7.2.tar.gz; \
# fi
# 2023-05-23 12:29:33 URL:https://www.openfst.org/twiki/pub/FST/FstDownload/openfst-1.7.2.tar.gz [1269292/1269292] -> "openfst-1.7.2.tar.gz" [1]
# tar xozf openfst-1.7.2.tar.gz
# cd openfst-1.7.2/ && \
# ...

# %%
# !bash extras/install_openblas.sh
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
#   368 |       LIOPT = MAX( DBLE( LIOPT ), DBLE( IWORK( 1 ) ) )
#       |              1
# ...
# gfortran -O2 -Wall -frecursive -fno-optimize-sibling-calls -m64 -fPIC -msse3 -mssse3 -msse4.1 -mavx -mavx2 -mfma -mavx2  -c -o zhegvx.o zhegvx.f
# gfortran -O2 -Wall -frecursive -fno-optimize-sibling-calls -m64 -fPIC -msse3 -mssse3 -msse4.1 -mavx -mavx2 -mfma -mavx2  -c -o zherfs.o zherfs.f
# gfortran -O2 -Wall -frecursive -fno-optimize-sibling-calls -m64 -fPIC -msse3 -mssse3 -msse4.1 -mavx -mavx2 -mfma -mavx2  -c -o zhesv.o zhesv.f
# gfortran -O2 -Wall -frecursive -fno-optimize-sibling-calls -m64 -fPIC -msse3 -mssse3 -msse4.1 -mavx -mavx2 -mfma -mavx2  -c -o zhesvx.o zhesvx.f
# gfortran -O2 -Wall -frecursive -fno-optimize-sibling-calls -m64 -fPIC -msse3 -mssse3 -msse4.1 -mavx -mavx2 -mfma -mavx2  -c -o zhetd2.o zhetd2.f
# zhetd2.f:251:21:
#
#   251 |             E( I ) = ALPHA
#       |                     1
# ...
# zhetd2.f:279:23:
#
# ...

# %%
os.chdir("/content/kaldi-master/src")
# !./configure --shared
# !make depend -j 2
# !make -j 2
# Out:
# Configuring KALDI to use MKL.
# Checking compiler c++ ...
# Checking OpenFst library in /content/kaldi-master/tools/openfst-1.7.2 ...
# Checking cub library in /content/kaldi-master/tools/cub-1.8.0 ...
# Performing OS specific configuration ...
# On Linux: Checking for linear algebra header files ...
# Configuring MKL library directory: Found /opt/intel/mkl/lib/intel64
# MKL libs MKL_LDLIBS = -L/opt/intel/mkl/lib/intel64 -Wl,-rpath=/opt/intel/mkl/lib/intel64 -l:libmkl_intel_lp64.so -l:libmkl_core.so -l:libmkl_sequential.so -ldl -lpthread -lm.
# MKL compile flags MKL_CXXFLAGS = -I/opt/intel/mkl/include.
# *** MKL self-reported version:
# Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
# Successfully configured for Linux with MKL libraries found in /opt/intel/mkl
# Using CUDA toolkit /usr/local/cuda (nvcc compiler and runtime libraries)
# INFO: Configuring Kaldi not to link with Speex. Don't worry, it's only needed if
# ...

# %%
os.chdir("/content/kaldi-master/egs/yesno/s5")
# !bash run.sh
# Out:
# --2023-05-23 15:03:44--  http://www.openslr.org/resources/1/waves_yesno.tar.gz
# Resolving www.openslr.org (www.openslr.org)... 46.101.158.64
# Connecting to www.openslr.org (www.openslr.org)|46.101.158.64|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://us.openslr.org/resources/1/waves_yesno.tar.gz [following]
# --2023-05-23 15:03:44--  https://us.openslr.org/resources/1/waves_yesno.tar.gz
# Resolving us.openslr.org (us.openslr.org)... 46.101.158.64
# Connecting to us.openslr.org (us.openslr.org)|46.101.158.64|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4703754 (4.5M) [application/x-gzip]
# Saving to: ‘waves_yesno.tar.gz’
#
# waves_yesno.tar.gz  100%[===================>]   4.49M  --.-KB/s    in 0.1s
#
# 2023-05-23 15:03:44 (37.0 MB/s) - ‘waves_yesno.tar.gz’ saved [4703754/4703754]
#
# waves_yesno/
# waves_yesno/1_0_0_0_0_0_1_1.wav
# waves_yesno/1_1_0_0_1_0_1_0.wav
# waves_yesno/1_0_1_1_1_1_0_1.wav
# ...

# %%
! bash ufpalign.sh ~/git-all/kaldi demo/M-001.wav demo/M-001.txt mono
# Out:
# bash: ufpalign.sh: No such file or directory

# %%
! KALDI_ROOT=$HOME/work/git/kaldi bash ufpalign.sh \
    --beam 20 --retry-beam 120 --no-syllphones true
    /tmp/SP_EF_156_clipped_4.wav /tmp/SP_EF_156_clipped_4.txt mono

# %%
# !ls "/tmp"
# Out:
# dap_multiplexer.9c9a4f23f693.root.log.INFO.20230523-121704.85
# dap_multiplexer.INFO
# debugger_1rofod1qy8
# directoryprefetcher_binary.9c9a4f23f693.root.log.INFO.20230523-122729.2828
# directoryprefetcher_binary.INFO
# drivefs_ipc.0
# drivefs_ipc.0_shell
# initgoogle_syslog_dir.0
# language_service.9c9a4f23f693.root.log.INFO.20230523-121807.390
# language_service.9c9a4f23f693.root.log.INFO.20230523-150304.94038
# language_service.INFO
# pyright-395-m8VbhecizbLY
# pyright-94043-8m7kbK5KYo4X
# pyright-94043-Dmsh5YkDS5YP
# python-languageserver-cancellation
